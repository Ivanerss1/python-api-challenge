# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []
# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 586

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapuskasing
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | hobyo
# Processing Record 5 of Set 1 | mbamba bay
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | udachny
# Processing Record 8 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | forster
# Processing Record 11 of Set 1 | karratha
# Processing Record 12 of Set 1 | kavala
# Processing Record 13 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 14 of Set 1 | zeya
# Processing Record 15 of Set 1 | ta`u
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | wailua homesteads
# Processing Record 18 of Set 1 | pisco
# Processing Record 19 of Set 1 | nar'yan-mar
# Processing Record 20 of Set 1 | papao
# Processing Record 21 of Set 1 | moanda
# Processing Record 22 of Set 1 | klyuchi
# Processing Record 23 of Set 1 | dubinino
# Processing Record 24 of Set 1 | satupa'itea
# City not found. Skipping...
# Processing Record 25 of Set 1 | grytviken
# Processing Record 26 of Set 1 | urengoy
# Processing Record 27 of Set 1 | kavieng
# Processing Record 28 of Set 1 | aroma
# Processing Record 29 of Set 1 | arkhangel'sk
# Processing Record 30 of Set 1 | machali
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | blackmans bay
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | polyarnyy
# Processing Record 35 of Set 1 | jining
# Processing Record 36 of Set 1 | yurty
# Processing Record 37 of Set 1 | targuist
# Processing Record 38 of Set 1 | acarau
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | moree
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | tamanrasset
# Processing Record 43 of Set 1 | vakarai
# Processing Record 44 of Set 1 | edinburgh of the seven seas
# Processing Record 45 of Set 1 | whitehorse
# Processing Record 46 of Set 1 | lethem
# Processing Record 47 of Set 1 | adamstown
# Processing Record 48 of Set 1 | zelenogorskiy
# Processing Record 49 of Set 1 | puerto natales
# Processing Record 50 of Set 1 | cambria
# Processing Record 0 of Set 2 | kasangulu
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | klaksvik
# Processing Record 5 of Set 2 | ujar
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | port lincoln
# Processing Record 9 of Set 2 | minab
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | bamboo flat
# Processing Record 12 of Set 2 | sovetskiy
# Processing Record 13 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 14 of Set 2 | levuka
# Processing Record 15 of Set 2 | ust'-barguzin
# Processing Record 16 of Set 2 | el tigre
# Processing Record 17 of Set 2 | san antonio de pale
# Processing Record 18 of Set 2 | brzeg
# Processing Record 19 of Set 2 | isafjordur
# Processing Record 20 of Set 2 | waitangi
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | college
# Processing Record 23 of Set 2 | saipan
# Processing Record 24 of Set 2 | caister-on-sea
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | oum hadjer
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | longyearbyen
# Processing Record 29 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 30 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | vadso
# Processing Record 33 of Set 2 | tangalle
# Processing Record 34 of Set 2 | queenstown
# Processing Record 35 of Set 2 | kayes
# Processing Record 36 of Set 2 | ariquemes
# Processing Record 37 of Set 2 | ancud
# Processing Record 38 of Set 2 | anadyr
# Processing Record 39 of Set 2 | lamarque
# Processing Record 40 of Set 2 | alaghsas
# Processing Record 41 of Set 2 | laguna
# Processing Record 42 of Set 2 | hamilton
# Processing Record 43 of Set 2 | atafu village
# Processing Record 44 of Set 2 | aasiaat
# Processing Record 45 of Set 2 | sarlat-la-caneda
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | invercargill
# Processing Record 48 of Set 2 | agnibilekrou
# Processing Record 49 of Set 2 | west island
# Processing Record 0 of Set 3 | bilibino
# Processing Record 1 of Set 3 | n'zeto
# Processing Record 2 of Set 3 | yasnyy
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | cannonvale
# Processing Record 5 of Set 3 | ti port-de-paix
# Processing Record 6 of Set 3 | tazovsky
# Processing Record 7 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 8 of Set 3 | loukhi
# Processing Record 9 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 10 of Set 3 | ocos
# Processing Record 11 of Set 3 | zabaykal'sk
# Processing Record 12 of Set 3 | olonkinbyen
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 
# Processing Record 39 of Set 4 | avarua
# Processing Record 40 of Set 4 | fort st. john
# Processing Record 41 of Set 4 | kaihua
# Processing Record 42 of Set 4 | vorgashor
# Processing Record 43 of Set 4 | portland
# Processing Record 44 of Set 4 | vila franca do campo
# Processing Record 45 of Set 4 | delmas
# Processing Record 46 of Set 4 | tan an
# Processing Record 47 of Set 4 | bafoulabe
# Processing Record 48 of Set 4 | rawlins
# Processing Record 49 of Set 4 | huocheng
# City not found. Skipping...
# Processing Record 0 of Set 5 | katsuura
# Processing Record 1 of Set 5 | nogliki
# Processing Record 2 of Set 5 | coquimbo
# Processing Record 3 of Set 5 | minas de marcona
# Processing Record 4 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 5 of Set 5 | burang
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | nova sintra
# Processing Record 8 of Set 5 | port mathurin
# Processing Record 9 of Set 5 | zapata
# Processing Record 10 of Set 5 | aldama
# Processing Record 11 of Set 5 | bordighera
# Processing Record 12 of Set 5 | utrik
# Processing Record 13 of Set 5 | lionel town
# Processing Record 14 of Set 5 | port augusta
# Processing Record 15 of Set 5 | helena valley west central
# Processing Record 16 of Set 5 | zaozersk
# Processing Record 17 of Set 5 | camenca
# Processing Record 18 of Set 5 | fort-shevchenko
# Processing Record 19 of Set 5 | glendive
# Processing Record 20 of Set 5 | taltal
# Processing Record 21 of Set 5 | keflavik
# Processing Record 22 of Set 5 | vikulovo
# Processing Record 23 of Set 5 | chibougamau
# Processing Record 24 of Set 5 | kayangel
# Processing Record 25 of Set 5 | praia da vitoria
# Processing Record 26 of Set 5 | yambio
# Processing Record 27 of Set 5 | putina
# Processing Record 28 of Set 5 | ellsworth
# Processing Record 29 of Set 5 | maryville
# Processing Record 30 of Set 5 | chonchi
# Processing Record 31 of Set 5 | hirara
# Processing Record 32 of Set 5 | altay
# Processing Record 33 of Set 5 | gagarin
# Processing Record 34 of Set 5 | lagunillas
# Processing Record 35 of Set 5 | puerto armuelles
# Processing Record 36 of Set 5 | ojinaga
# Processing Record 37 of Set 5 | shingu
# Processing Record 38 of Set 5 | aq qayeh
# City not found. Skipping...
# Processing Record 39 of Set 5 | luganville
# Processing Record 40 of Set 5 | kuqa
# Processing Record 41 of Set 5 | opuwo
# Processing Record 42 of Set 5 | kuanda
# Processing Record 43 of Set 5 | aquitania
# Processing Record 44 of Set 5 | sena madureira
# Processing Record 45 of Set 5 | rochefort-du-gard
# Processing Record 46 of Set 5 | ballito
# Processing Record 47 of Set 5 | bozeman
# Processing Record 48 of Set 5 | lazaro cardenas
# Processing Record 49 of Set 5 | primero de enero
# Processing Record 0 of Set 6 | kerikeri
# Processing Record 1 of Set 6 | ban phan don
# Processing Record 2 of Set 6 | san andres
# Processing Record 3 of Set 6 | stara vyzhivka
# Processing Record 4 of Set 6 | ust-nera
# Processing Record 5 of Set 6 | alotau
# Processing Record 6 of Set 6 | rodionovo-nesvetaiskoye
# Processing Record 7 of Set 6 | qaqortoq
# Processing Record 8 of Set 6 | sodankyla
# Processing Record 9 of Set 6 | stjordalshalsen
# Processing Record 10 of Set 6 | arivonimamo
# Processing Record 11 of Set 6 | greiz
# Processing Record 12 of Set 6 | naze
# Processing Record 13 of Set 6 | fort mcmurray
# Processing Record 14 of Set 6 | rongelap
# Processing Record 15 of Set 6 | panamaram
# Processing Record 16 of Set 6 | shetpe
# Processing Record 17 of Set 6 | iquique
# Processing Record 18 of Set 6 | as sulayyil
# Processing Record 19 of Set 6 | rio grande
# Processing Record 20 of Set 6 | karymskoye
# Processing Record 21 of Set 6 | constantia
# Processing Record 22 of Set 6 | yatou
# Processing Record 23 of Set 6 | conduaga
# Processing Record 24 of Set 6 | beyneu
# Processing Record 25 of Set 6 | svilengrad
# Processing Record 26 of Set 6 | piti village
# Processing Record 27 of Set 6 | waingapu
# Processing Record 28 of Set 6 | morondava
# Processing Record 29 of Set 6 | chamical
# Processing Record 30 of Set 6 | miles city
# Processing Record 31 of Set 6 | hazaribagh
# Processing Record 32 of Set 6 | san patricio
# Processing Record 33 of Set 6 | chebba
# Processing Record 34 of Set 6 | kununurra
# Processing Record 35 of Set 6 | mili
# Processing Record 36 of Set 6 | sidi akkacha
# Processing Record 37 of Set 6 | bako
# Processing Record 38 of Set 6 | tofol
# Processing Record 39 of Set 6 | vernal
# Processing Record 40 of Set 6 | puerto baquerizo moreno
# Processing Record 41 of Set 6 | nemuro
# Processing Record 42 of Set 6 | port saint john's
# Processing Record 43 of Set 6 | barra do corda
# Processing Record 44 of Set 6 | tarko-sale
# Processing Record 45 of Set 6 | carnarvon
# Processing Record 46 of Set 6 | flying fish cove
# Processing Record 47 of Set 6 | coahuayana de hidalgo
# Processing Record 48 of Set 6 | fale old settlement
# Processing Record 49 of Set 6 | parauapebas
# Processing Record 0 of Set 7 | visby
# Processing Record 1 of Set 7 | oshawa
# Processing Record 2 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 3 of Set 7 | rakops
# Processing Record 4 of Set 7 | happy valley-goose bay
# Processing Record 5 of Set 7 | kismayo
# Processing Record 6 of Set 7 | cairns city
# City not found. Skipping...
# Processing Record 7 of Set 7 | padangsidempuan
# Processing Record 8 of Set 7 | badger
# Processing Record 9 of Set 7 | poljcane
# Processing Record 10 of Set 7 | mar de espanha
# Processing Record 11 of Set 7 | niquelandia
# Processing Record 12 of Set 7 | dubrovnik
# Processing Record 13 of Set 7 | makar'yev
# Processing Record 14 of Set 7 | pinheiro machado
# Processing Record 15 of Set 7 | camana
# Processing Record 16 of Set 7 | sumbe
# Processing Record 17 of Set 7 | fraserburgh
# Processing Record 18 of Set 7 | fallon
# Processing Record 19 of Set 7 | al-`ula
# City not found. Skipping...
# Processing Record 20 of Set 7 | rosetta
# Processing Record 21 of Set 7 | touros
# Processing Record 22 of Set 7 | lihue
# Processing Record 23 of Set 7 | sitka
# Processing Record 24 of Set 7 | dakhla
# Processing Record 25 of Set 7 | hasaki
# Processing Record 26 of Set 7 | odiongan
# Processing Record 27 of Set 7 | huddinge
# Processing Record 28 of Set 7 | ola
# Processing Record 29 of Set 7 | bay harbor
# Processing Record 30 of Set 7 | moose jaw
# Processing Record 31 of Set 7 | amahai
# Processing Record 32 of Set 7 | sarina
# Processing Record 33 of Set 7 | asau village
# City not found. Skipping...
# Processing Record
of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 7 of Set 9 | isle of lewis
# City not found. Skipping...
# Processing Record 8 of Set 9 | konarka
# Processing Record 9 of Set 9 | qarazhal
# Processing Record 10 of Set 9 | saint-joseph
# Processing Record 11 of Set 9 | kenora
# Processing Record 12 of Set 9 | nizhneangarsk
# Processing Record 13 of Set 9 | aykhal
# Processing Record 14 of Set 9 | quelimane
# Processing Record 15 of Set 9 | greymouth
# Processing Record 16 of Set 9 | shizuishan
# Processing Record 17 of Set 9 | vanimo
# Processing Record 18 of Set 9 | avon
# Processing Record 19 of Set 9 | lodja
# Processing Record 20 of Set 9 | federal
# Processing Record 21 of Set 9 | farshut
# Processing Record 22 of Set 9 | betio village
# Processing Record 23 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 24 of Set 9 | wamba
# Processing Record 25 of Set 9 | nabire
# Processing Record 26 of Set 9 | saudarkrokur
# Processing Record 27 of Set 9 | hanzhong
# Processing Record 28 of Set 9 | fada
# Processing Record 29 of Set 9 | sabancuy
# Processing Record 30 of Set 9 | tralee
# Processing Record 31 of Set 9 | zagora
# Processing Record 32 of Set 9 | kabala
# Processing Record 33 of Set 9 | menongue
# Processing Record 34 of Set 9 | haiku-pauwela
# Processing Record 35 of Set 9 | tam ky
# Processing Record 36 of Set 9 | axim
# Processing Record 37 of Set 9 | sablayan
# Processing Record 38 of Set 9 | nadym
# Processing Record 39 of Set 9 | kattivakkam
# Processing Record 40 of Set 9 | pemangkat
# Processing Record 41 of Set 9 | labrador city
# Processing Record 42 of Set 9 | lensk
# Processing Record 43 of Set 9 | acapulco de juarez
# Processing Record 44 of Set 9 | skovorodino
# Processing Record 45 of Set 9 | okhotsk
# Processing Record 46 of Set 9 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 47 of Set 9 | abony
# Processing Record 48 of Set 9 | santa elena de uairen
# Processing Record 49 of Set 9 | mafinga
# Processing Record 0 of Set 10 | eirunepe
# Processing Record 1 of Set 10 | shamakhi
# Processing Record 2 of Set 10 | kourou
# Processing Record 3 of Set 10 | tongren
# Processing Record 4 of Set 10 | issa
# Processing Record 5 of Set 10 | calvinia
# Processing Record 6 of Set 10 | fortuna
# Processing Record 7 of Set 10 | tsiombe
# Processing Record 8 of Set 10 | xai-xai
# Processing Record 9 of Set 10 | midvagur
# Processing Record 10 of Set 10 | kariba
# Processing Record 11 of Set 10 | juegang
# Processing Record 12 of Set 10 | gaiman
# Processing Record 13 of Set 10 | krasnyy chikoy
# Processing Record 14 of Set 10 | sakakah
# Processing Record 15 of Set 10 | souillac
# Processing Record 16 of Set 10 | khalis
# Processing Record 17 of Set 10 | zaghouan
# Processing Record 18 of Set 10 | prado
# Processing Record 19 of Set 10 | afaahiti
# Processing Record 20 of Set 10 | kargasok
# Processing Record 21 of Set 10 | nongpoh
# Processing Record 22 of Set 10 | mhamid
# Processing Record 23 of Set 10 | hithadhoo
# Processing Record 24 of Set 10 | znamenskoye
# Processing Record 25 of Set 10 | mbabane
# Processing Record 26 of Set 10 | minsk mazowiecki
# Processing Record 27 of Set 10 | jayanca
# Processing Record 28 of Set 10 | lorengau
# Processing Record 29 of Set 10 | vung tau
# Processing Record 30 of Set 10 | kiuruvesi
# Processing Record 31 of Set 10 | tanki leendert
# City not found. Skipping...
# Processing Record 32 of Set 10 | grootfontein
# Processing Record 33 of Set 10 | mbandaka
# Processing Record 34 of Set 10 | gurlan
# Processing Record 35 of Set 10 | belo sur tsiribihina
# Processing Record 36 of Set 10 | chandla
# Processing Record 37 of Set 10 | ocher
# Processing Record 38 of Set 10 | skawina
# Processing Record 39 of Set 10 | codrington
# Processing Record 40 of Set 10 | priozersk
# Processing Record 41 of Set 10 | qarqaraly
# Processing Record 42 of Set 10 | nkove
# Processing Record 43 of Set 10 | dadonghai
# City not found. Skipping...
# Processing Record 44 of Set 10 | garoua
# Processing Record 45 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 46 of Set 10 | purranque
# Processing Record 47 of Set 10 | mungwi
# Processing Record 48 of Set 10 | lockwood
# Processing Record 49 of Set 10 | kyzylorda
# Processing Record 0 of Set 11 | sishilichengzi
# City not found. Skipping...
# Processing Record 1 of Set 11 | puerto real
# Processing Record 2 of Set 11 | vredenburg
# City not found. Skipping...
# Processing Record 3 of Set 11 | salekhard
# Processing Record 4 of Set 11 | tuxtepec
# Processing Record 5 of Set 11 | alo
# Processing Record 6 of Set 11 | arar
# Processing Record 7 of Set 11 | selfoss
# Processing Record 8 of Set 11 | padang
# Processing Record 9 of Set 11 | callao
# Processing Record 10 of Set 11 | mermoz boabab
# Processing Record 11 of Set 11 | howrah
# Processing Record 12 of Set 11 | page
# Processing Record 13 of Set 11 | nchelenge
# Processing Record 14 of Set 11 | igrim
# Processing Record 15 of Set 11 | fasa
# Processing Record 16 of Set 11 | kani keli
# Processing Record 17 of Set 11 | nova era
# Processing Record 18 of Set 11 | villa emilio carranza
# Processing Record 19 of Set 11 | tal'menka
# Processing Record 20 of Set 11 | kailua-kona
# Processing Record 21 of Set 11 | mujiayingzi
# Processing Record 22 of Set 11 | beykonak
# Processing Record 23 of Set 11 | pontianak
# Processing Record 24 of Set 11 | daru
# Processing Record 25 of Set 11 | edson
# Processing Record 26 of Set 11 | san blas
# Processing Record 27 of Set 11 | darwin
# Processing Record 28 of Set 11 | oktyabr'sk
# Processing Record 29 of Set 11 | porbandar
# Processing Record 30 of Set 11 | guiping
# Processing Record 31 of Set 11 | kill devil hills
# Processing Record 32 of Set 11 | gazli
# Processing Record 33 of Set 11 | san agustin de valle fertil
# Processing Record 34 of Set 11 | bratsk
# Processing Record 35 of Set 11 | luau
# Processing Record 36 of Set 11 | sault ste. marie
# Processing Record 37 of Set 11 | westport
# Processing Record 38 of Set 11 | maych'ew
# Processing Record 39 of Set 11 | isangel
# Processing Record 40 of Set 11 | watampone
# Processing Record 41 of Set 11 | yuma
# Processing Record 42 of Set 11 | san julian
# Processing Record 43 of Set 11 | dzhalagash
# Processing Record 44 of Set 11 | taroa
# Processing Record 45 of Set 11 | revda
# Processing Record 46 of Set 11 | susuman
# Processing Record 47 of Set 11 | kruisfontein
# Processing Record 48 of Set 11 | crane
# Processing Record 49 of Set 11 | turpan
# Processing Record 0 of Set 12 | rabaul
# Processing Record 1 of Set 12 | hadibu
# Processing Record 2 of Set 12 | ma'rib
# Processing Record 3 of Set 12 | usinsk
# Processing Record 4 of Set 12 | dogondoutchi
# Processing Record 5 of Set 12 | khromtau
# Processing Record 6 of Set 12 | hafar al-batin
# Processing Record 7 of Set 12 | merizo village
# Processing Record 8 of Set 12 | valle hermoso
# Processing Record 9 of Set 12 | gweru
# Processing Record 10 of Set 12 | seymour
# Processing Record 11 of Set 12 | ribas do rio pardo
# Processing Record 12 of Set 12 | lambarene
# Processing Record 13 of Set 12 | kirensk
# Processing Record 14 of Set 12 | linqiong
# Processing Record 15 of Set 12 | milazzo
# Processing Record 16 of Set 12 | beneditinos
# Processing Record 17 of Set 12 | ardestan
# Processing Record 18 of Set 12 | qobustan
# Processing Record 19 of Set 12 | strzelno
# Processing Record 20 of Set 12 | yuli
# Processing Record 21 of Set 12 | falam
# Processing Record 22 of Set 12 | franceville
# Processing Record 23 of Set 12 | shanwei
# Processing Record 24 of Set 12 | island harbour
# Processing Record 25 of Set 12 | gualeguay
# Processing Record 26 of Set 12 | clarence-rockland
# Processing Record 27 of Set 12 | beidaihehaibin
# Processing Record 28 of Set 12 | kokopo
# Processing Record 29 of Set 12 | saldanha
# Processing Record 30 of Set 12 | coulounieix
# Processing Record 31 of Set 12 | taoudenni
# Processing Record 32 of Set 12 | trincomalee
# Processing Record 33 of Set 12 | vokhtoga
# Processing Record 34 of Set 12 | nha trang
# Processing Record 35 of Set 12 | inari
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Display sample data

city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   kapuskasing  49.4169 -82.4331     22.56        31           5        4.25
# 1       iqaluit  63.7506 -68.5145      5.39        93         100        1.79
# 2  puerto ayora  -0.7393 -90.3518     21.97        87          80        3.58
# 3         hobyo   5.3505  48.5268     24.72        83          99       12.81
# 4    mbamba bay -11.2833  34.7667     22.02        51           0        2.44
#
#   Country        Date
# 0      CA  1722798402
# 1      CA  1722798404
# 2      EC  1722798405
# 3      SO  1722798406
# 4      TZ  1722798407

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         kapuskasing  49.4169 -82.4331     22.56        31           5
# 1             iqaluit  63.7506 -68.5145      5.39        93         100
# 2        puerto ayora  -0.7393 -90.3518     21.97        87          80
# 3               hobyo   5.3505  48.5268     24.72        83          99
# 4          mbamba bay -11.2833  34.7667     22.02        51           0
#
#          Wind Speed Country        Date
# City_ID
# 0              4.25      CA  1722798402
# 1              1.79      CA  1722798404
# 2              3.58      EC  1722798405
# 3             12.81      SO  1722798406
# 4              2.44      TZ  1722798407

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]
# Incorporate the other graph properties
plt.scatter(x_values,y_values)
plt.title("City Max Latitude vs. Temperature (2024-06-17)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")



# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]

# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("City Latitude vs. Humidity (2024-06-17)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]

# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("City Latitude vs. Cloudiness (2024-06-17)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]


# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolors="black", linewidths=1, marker="o", alpha=0.8)
plt.title("City Latitude vs. Wind Speed (2024-06-17)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
from scipy.stats import linregress

def plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()

    print(f"R-squared value: {rvalue**2:.2f}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        kapuskasing  49.4169  -82.4331     22.56        31           5
# 1            iqaluit  63.7506  -68.5145      5.39        93         100
# 3              hobyo   5.3505   48.5268     24.72        83          99
# 6            udachny  66.4167  112.4000     14.87        54          16
# 7              tiksi  71.6872  128.8694     10.25        63         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.25      CA  1722798402
# 1              1.79      CA  1722798404
# 3             12.81      SO  1722798406
# 6              3.49      RU  1722798409
# 7              3.24      RU  1722798149

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             puerto ayora  -0.7393  -90.3518     21.97        87          80
# 4               mbamba bay -11.2833   34.7667     22.02        51           0
# 5        port-aux-francais -49.3500   70.2167      1.85        67          31
# 8                  forster -32.1667  152.5167      7.38       100         100
# 9                 karratha -20.7377  116.8463     17.94        57           0
#
#          Wind Speed Country        Date
# City_ID
# 2              3.58      EC  1722798405
# 4              2.44      TZ  1722798407
# 5             10.04      TF  1722798345
# 8              2.72      AU  1722798412
# 9              5.06      AU  1722798413

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 
                       x_label="Latitude", 
                       y_label="Max Temp", 
                       title="Latitude vs Max Temp", 
                       text_coordinates=(10, 0))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
# Out:
# R-squared value: 0.42
# The r-value is: 0.4213533084781663

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 
                       x_label="Latitude", 
                       y_label="Max Temp", 
                       title="Latitude vs Max Temp", 
                       text_coordinates=(-50, 30))
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
print(f"The r-value is: {rvalue**2}")
# Out:
# R-squared value: 0.66
# The r-value is: 0.656809415075158

# %% [markdown]
# **Discussion about the linear relationship:** the higher the latitume the hotter the tempeture is.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq, (11, 40), fontsize=15, color="red")

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Latitude vs Humidity Linear Regression')

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.0002094082762195083

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept
line_eq = f"y = {slope:.2f}x + {intercept:.2f}"

plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs Humidity Linear Regression (Southern Hemisphere)')
plt.annotate(line_eq, (min(x_values), min(y_values)), fontsize=15, color="red")

print(f"The r-value is: {rvalue**2}")
# Out:
# The r-value is: 0.01692602115484209

# %% [markdown]
# **Discussion about the linear relationship:** there is a week weak linear relationship

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere



x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, "r")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Latitude vs Cloudiness Linear Regression (Northern Hemisphere)')

print(f"The r-value is: {rvalue**2}")

plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}', (10, 40), fontsize=15, color='red')

# Show the plot
plt.show()
# Out:
# The r-value is: 0.027413678827927952

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, "r")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Latitude vs Cloudiness Linear Regression (Southern Hemisphere)')

print(f"The r-value is: {rvalue**2}")

plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}', (-30, 50), fontsize=15, color='red')
# Out:
# The r-value is: 0.02134896351034258
# Text(-30, 50, 'y = -0.45x + 45.04')

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

regress_values = x_values * slope + intercept

plt.scatter(x_values, y_values)

plt.plot(x_values, regress_values, "r")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('Latitude vs Wind Speed Linear Regression (Southern Hemisphere)')

print(f"The r-value is: {rvalue**2}")

plt.annotate(f'y = {round(slope, 2)}x + {round(intercept, 2)}', (-50, 12), fontsize=15, color='red')
# Out:
# The r-value is: 0.014788925372172152
# Text(-50, 12, 'y = -0.02x + 3.28')

# %% [markdown]
# **Discussion about the linear relationship:** there is a negative weak corralation
