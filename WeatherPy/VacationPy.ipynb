# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ca57eafe-9253-495a-b189-57867bfd350d" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
pd.set_option('display.max_rows', None)
city_data_df
# Out:
#      City_ID                         City      Lat       Lng  Max Temp  \
# 0          0                  kapuskasing  49.4169  -82.4331     22.56
# 1          1                      iqaluit  63.7506  -68.5145      5.39
# 2          2                 puerto ayora  -0.7393  -90.3518     21.97
# 3          3                        hobyo   5.3505   48.5268     24.72
# 4          4                   mbamba bay -11.2833   34.7667     22.02
# 5          5            port-aux-francais -49.3500   70.2167      1.85
# 6          6                      udachny  66.4167  112.4000     14.87
# 7          7                        tiksi  71.6872  128.8694     10.25
# 8          8                      forster -32.1667  152.5167      7.38
# 9          9                     karratha -20.7377  116.8463     17.94
# 10        10                       kavala  40.9397   24.4019     25.31
# 11        11                         zeya  53.7500  127.2667     17.84
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
city_data_df.hvplot.points('Lng', 'Lat', geo=True, tiles='OSM', size='Humidity', color='Max Temp', 
                           frame_width=800, frame_height=600, title='City Locations and Humidity')
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Max Temp,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities_df = city_data_df[(city_data_df['Max Temp'] > 21) & 
                               (city_data_df['Max Temp'] < 27) & 
                               (city_data_df['Cloudiness'] < 1) &
                               (city_data_df['Wind Speed'] < 4.5)]


# Drop any rows with null values
ideal_cities_df = ideal_cities_df.dropna()


# Display sample data
pd.set_option('display.max_rows', None)
ideal_cities_df
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 4          4     mbamba bay -11.2833   34.7667     22.02        51
# 33        33       targuist  34.9377   -4.3186     25.40        45
# 142      142     hammerfest  70.6634   23.6821     22.25        49
# 172      172      al qubbah  32.7616   22.2424     26.18        32
# 174      174    nova vicosa -17.8919  -39.3719     24.96        71
# 219      219      ellsworth  44.5434  -68.4195     25.65        80
# 228      228         shingu  33.7333  135.9833     25.27        92
# 253      253  fort mcmurray  56.7268 -111.3810     22.73        43
# 265      265     svilengrad  41.7667   26.2000     22.59        58
# 268      268      morondava -20.2833   44.2833     21.93        75
# 300      300      dubrovnik  42.6481   18.0922     25.80        69
# 307      307        rosetta  31.4044   30.4164     26.95        66
# 335      335   mersa matruh  31.3525   27.2453     26.91        75
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
columns = ["City", "Country", "Lat", "Lng", "Humidity"]

hotels_df = ideal_cities_df[columns]

hotels_df["Hotel Name"] = ""

hotels_df
# Out:
# /var/folders/qs/mkvg325s0yq72ghmghs9_kp00000gn/T/ipykernel_91691/2204294952.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotels_df["Hotel Name"] = ""
#               City Country      Lat       Lng  Humidity Hotel Name
# 4       mbamba bay      TZ -11.2833   34.7667        51
# 33        targuist      MA  34.9377   -4.3186        45
# 142     hammerfest      NO  70.6634   23.6821        49
# 172      al qubbah      LY  32.7616   22.2424        32
# 174    nova vicosa      BR -17.8919  -39.3719        71
# 219      ellsworth      US  44.5434  -68.4195        80
# 228         shingu      JP  33.7333  135.9833        92
# 253  fort mcmurray      CA  56.7268 -111.3810        43
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
places
# Out:
# {'type': 'FeatureCollection', 'features': []}

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel", "api_key": geoapify_key, "limit": 1}
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotels_df.iterrows():
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"


    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    places = response.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotels_df.loc[index, "Hotel Name"] = places["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotels_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotels_df.loc[index, 'City']} - nearest hotel: {hotels_df.loc[index, 'Hotel Name']}")

# Display sample data
hotels_df
# Out:
# Starting hotel search
# mbamba bay - nearest hotel: Bio Camp lodge
# targuist - nearest hotel: No hotel found
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# al qubbah - nearest hotel: No hotel found
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# ellsworth - nearest hotel: The Sanctuary B&B
# shingu - nearest hotel: ホテルニューパレス
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# svilengrad - nearest hotel: George Family Hotel
# morondava - nearest hotel: Hotel Sharon Menabe
# dubrovnik - nearest hotel: Bellevue
# rosetta - nearest hotel: No hotel found
# mersa matruh - nearest hotel: صقور
# la passe - nearest hotel: L'Estuaire
# qarazhal - nearest hotel: No hotel found
# quelimane - nearest hotel: Mabassa
# shizuishan - nearest hotel: No hotel found
# hanzhong - nearest hotel: 东珅国宾大酒店
# abony - nearest hotel: No hotel found
# shamakhi - nearest hotel: Şirvan Otel \ Şamaxı
# kyzylorda - nearest hotel: Нур
# nova era - nearest hotel: Pousada São José
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotels_df.hvplot.points(
    'Lng', 'Lat', 
    geo=True, 
    tiles='OSM', 
    size='Humidity', 
    color='Country', 
    hover_cols=['City', 'Country', 'Hotel Name'], 
    frame_width=800, 
    frame_height=600, 
    title='Hotel Locations'
)
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Country,Humidity,City,Hotel Name)
